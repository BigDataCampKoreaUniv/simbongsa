# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import pdvega

# %%
import re

# %%
# %matplotlib inline

# %% [markdown]
# ___
# ## 한글깨짐 방지

# %%
import matplotlib as mpl
import matplotlib.font_manager as fm

# %%
print ('버전: ', mpl.__version__)
print ('설치 위치: ', mpl.__file__)
print ('설정 위치: ', mpl.get_configdir())
print ('캐시 위치: ', mpl.get_cachedir())
# Out:
# 버전:  2.1.0
# 설치 위치:  /Users/sanghyub/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py
# 설정 위치:  /Users/sanghyub/.matplotlib
# 캐시 위치:  /Users/sanghyub/.matplotlib

# %%
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')

# %%
font_list[:10]
# Out:
# ['/Library/Fonts/Arial Bold.ttf',
#  '/System/Library/Assets/com_apple_MobileAsset_Font3/aff3c8ec47a0868e3cda1072abc49380aeebe50c.asset/AssetData/OsakaMono.ttf',
#  '/Library/Fonts/Georgia Bold.ttf',
#  '/Library/Fonts/Georgia.ttf',
#  '/Library/Fonts/Arial Italic.ttf',
#  '/Library/Fonts/Verdana Italic.ttf',
#  '/Library/Fonts/Arial Bold Italic.ttf',
#  '/System/Library/Assets/com_apple_MobileAsset_Font3/20d2e557b080b38599efc6c4e7945218db3f3b3d.asset/AssetData/ToppanBunkyuMincho-Regular.otf',
#  '/System/Library/Fonts/SFCompactText-Semibold.otf',
#  '/Library/Fonts/STIXIntUpDReg.otf']

# %%
print('# 설정 되어있는 폰트 사이즈')
print (plt.rcParams['font.size'] ) 
print('# 설정 되어있는 폰트 글꼴')
print (plt.rcParams['font.family'] )
# Out:
# # 설정 되어있는 폰트 사이즈
# 10.0
# # 설정 되어있는 폰트 글꼴
# ['AppleGothic']

# %%
plt.rcParams["font.family"] = 'AppleGothic'

# %%
print ('설정파일 위치: ', mpl.matplotlib_fname())
# Out:
# 설정파일 위치:  /Users/sanghyub/anaconda/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc

# %%
mpl.matplotlib_fname()
# Out:
# '/Users/sanghyub/anaconda/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc'

# %% [markdown]
# ---

# %%
data = pd.read_csv('./forspss.csv', encoding='euc-kr')

# %%
df = data.iloc[:,:16]

# %%
df2 = data.iloc[:,:16]

# %%
1 = '생활 편의 지원 - 급식소 배식, 유아/노인 활동 보조, 차량 봉사 등'

# %%
2= '주거 환경 - 요양원 청소, 공공시설 환경미화 등'

# %%
3='상담 - 청소년 상담, 법률 상담,  수화통역 봉사등'

# %%
4='교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등'

# %%
5='보건의료 - 요양원 혈압, 혈당 검사, 호스피스 자원봉사 , 심폐소생술 홍보등'

# %%
6='문화체육 - 어린이 체육교실, 노인 음악 교실, 체육회 보조, 음악회 보조, 전시회 보조등'

# %%
7='환경 - 환경교육,  절전 캠페인등'

# %%
8='인권 - 제 3세계, 청소년 노동인권등'

# %%
9='국제협력 - 번역,  NGO등'

# %%
10='농어촌 - 농어촌 야학, 농총활동등'

# %%
11='행정지원'
# Out:
#   File "<ipython-input-50-edbdcaa784a7>", line 1
#     11='행정지원'
#              ^
# SyntaxError: can't assign to literal

# %%
12='재해/ 재난 - 심폐소생술 교육, 구호활동'

# %%
13='관심없음'

# %% [markdown]
# ## Preprocessing

# %%
df.age.unique()
# Out:
# array([25, 22, 20, 27, 24, 21, 26, 23, 38, 28])

# %%
age=data.groupby('age').mean()

# %%
df.name.str.replace('*','')

# %% [markdown]
# '생활 편의 지원 - 급식소 배식, 유아/노인 활동 보조, 차량 봉사 등',1
# '주거 환경 - 요양원 청소, 공공시설 환경미화 등',2
# '상담 - 청소년 상담, 법률 상담,  수화통역 봉사등' ,3
# '교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등',4
# '보건의료 - 요양원 혈압, 혈당 검사, 호스피스 자원봉사 , 심폐소생술 홍보등',5
# '문화체육 - 어린이 체육교실, 노인 음악 교실, 체육회 보조, 음악회 보조, 전시회 보조등',6
# '환경 - 환경교육,  절전 캠페인등',7
# '인권 - 제 3세계, 청소년 노동인권등',8
# '국제협력 - 번역,  NGO등',9
# '농어촌 - 농어촌 야학, 농총활동등',10
# '행정지원',11
# '재해/ 재난 - 심폐소생술 교육, 구호활동',12
# '관심없음',13

# %%
df.favor_vol.replace('교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등', 4, inplace=True)

# %%
df.favor_vol.replace('생활 편의 지원 - 급식소 배식, 유아/노인 활동 보조, 차량 봉사 등', 1, inplace=True)

# %%
df.favor_vol.replace('주거 환경 - 요양원 청소, 공공시설 환경미화 등', 2, inplace=True)

# %%
df.favor_vol.replace('상담 - 청소년 상담, 법률 상담,  수화통역 봉사등', 3, inplace=True)

# %%
df.favor_vol.replace('보건의료 - 요양원 혈압, 혈당 검사, 호스피스 자원봉사 , 심폐소생술 홍보등', 5, inplace=True)

# %%
df.favor_vol.replace('문화체육 - 어린이 체육교실, 노인 음악 교실, 체육회 보조, 음악회 보조, 전시회 보조등',6 , inplace=True)

# %%
df.favor_vol.replace('환경 - 환경교육,  절전 캠페인등',7, inplace=True)

# %%
df.favor_vol.replace('인권 - 제 3세계, 청소년 노동인권등',8  , inplace=True)

# %%
df.favor_vol.replace('국제협력 - 번역,  NGO등',9   , inplace=True)

# %%
df.favor_vol.replace('농어촌 - 농어촌 야학, 농총활동등',10 , inplace=True)

# %%
df.favor_vol.replace('행정지원',11 , inplace=True)
df.favor_vol.replace('재해/ 재난 - 심폐소생술 교육, 구호활동',12, inplace=True) 
df.favor_vol.replace('관심없음',13, inplace=True)

# %%
df.favor_vol.replace('',14, inplace=True)

# %%
df.favor_vol.str.replace(pat=,repl='0')
# Out:
#   File "<ipython-input-291-0c2fd6577a48>", line 1
#     df.favor_vol.str.replace(pat=,repl='0')
#                                  ^
# SyntaxError: invalid syntax

# %%
'생활 편의 지원 - 급식소 배식, 유아/노인 활동 보조, 차량 봉사 등',1
'주거 환경 - 요양원 청소, 공공시설 환경미화 등',2
'상담 - 청소년 상담, 법률 상담,  수화통역 봉사등' ,3 
'교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등',4  
'보건의료 - 요양원 혈압, 혈당 검사, 호스피스 자원봉사 , 심폐소생술 홍보등',5
'문화체육 - 어린이 체육교실, 노인 음악 교실, 체육회 보조, 음악회 보조, 전시회 보조등',6 
'환경 - 환경교육,  절전 캠페인등',7  
'인권 - 제 3세계, 청소년 노동인권등',8  
'국제협력 - 번역,  NGO등',9  
'농어촌 - 농어촌 야학, 농총활동등',10  
'행정지원',11
'재해/ 재난 - 심폐소생술 교육, 구호활동',12  
'관심없음',13

# %%
df.favor_vol.str.replace(pat=r'생활 편의 지원 - 급식소 배식, 유아/노인 활동 보조, 차량 봉사 등',repl='1')
# Out:
# 0
# 1     교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등, 보건의료 - 요양원 ...
# 2     1, 상담 - 청소년 상담, 법률 상담,  수화통역 봉사등, 교육 - 방과후 교육,...
# 3                                                   NaN
# 4     상담 - 청소년 상담, 법률 상담,  수화통역 봉사등, 교육 - 방과후 교육, 초등...
# 5                                                   NaN
# 6                      1, 상담 - 청소년 상담, 법률 상담,  수화통역 봉사등
# 7                                                   NaN
# 8     교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등, 국제협력 - 번역, ...
# 9                                                   NaN
# 10    주거 환경 - 요양원 청소, 공공시설 환경미화 등, 문화체육 - 어린이 체육교실, ...
# 11    교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등, 인권 - 제 3세계,...
# 12    1, 상담 - 청소년 상담, 법률 상담,  수화통역 봉사등, 교육 - 방과후 교육,...
# 13    1, 교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등, 문화체육 - 어...
# 14                                                   홍보
# 15    교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등, 보건의료 - 요양원 ...
# 16                                                  NaN
# 17             1, 상담 - 청소년 상담, 법률 상담,  수화통역 봉사등, 유기견 봉사
# ...

# %%
df.favor_vol =df.favor_vol.str.replace(pat=r'교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등',repl='4')

# %%
df.favor_vol =df.favor_vol.str.replace(pat=r'생활 편의 지원 - 급식소 배식, 유아/노인 활동 보조, 차량 봉사 등',repl='1')

# %%
df.favor_vol =df.favor_vol.str.replace(pat=r'주거 환경 - 요양원 청소, 공공시설 환경미화 등',repl='2')

# %%
df.favor_vol =df.favor_vol.str.replace(pat=r'상담 - 청소년 상담, 법률 상담,  수화통역 봉사등',repl='3')

# %%
df.favor_vol =df.favor_vol.str.replace(pat=r'보건의료 - 요양원 혈압, 혈당 검사, 호스피스 자원봉사 , 심폐소생술 홍보등',repl='5')

# %%
df.favor_vol =df.favor_vol.str.replace(pat=r'문화체육 - 어린이 체육교실, 노인 음악 교실, 체육회 보조, 음악회 보조, 전시회 보조등',repl='6')

# %%
df.favor_vol =df.favor_vol.str.replace(pat=r'환경 - 환경교육,  절전 캠페인등',repl='7')

# %%
df.favor_vol =df.favor_vol.str.replace(pat=r'인권 - 제 3세계, 청소년 노동인권등',repl='8')

# %%
df.favor_vol =df.favor_vol.str.replace(pat=r'국제협력 - 번역,  NGO등',repl='9')

# %%
df.favor_vol =df.favor_vol.str.replace(pat=r'농어촌 - 농어촌 야학, 농총활동등',repl='10')

# %%
df.favor_vol =df.favor_vol.str.replace(pat=r'행정지원',repl='11')

# %%
df.favor_vol =df.favor_vol.str.replace(pat=r'재해/ 재난 - 심폐소생술 교육, 구호활동',repl='12')

# %%
df.favor_vol =df.favor_vol.str.replace(pat=r'관심없음',repl='13')

# %%
df.favor_vol.str.replace('Nan','0')
# Out:
# 0
# 1                  4, 5, 7
# 2        1, 3, 4, 5, 6, 10
# 3                      NaN
# 4              3, 4, 7, 11
# 5                      NaN
# 6                     1, 3
# 7                      NaN
# 8                 4, 9, 11
# 9                      NaN
# 10                    2, 6
# 11                    4, 8
# 12             1, 3, 4, 11
# 13              1, 4, 6, 7
# 14                      홍보
# 15       4, 5, 6, 7, 9, 12
# 16                     NaN
# 17            1, 3, 유기견 봉사
# 18                     NaN
# 19                      전체
# 20             4, 8, 9, 12
# 21             1, 6, 7, 11
# 22                     NaN
# 23       3, 4, 6, 8, 9, 11
# 24                4, 8, 11
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                6, 7, 11
#               ...
# 64                4, 7, 11
# 65                     NaN
# 66                 4, 5, 6
# 67             1, 2, 4, 10
# ...

# %%
df.favor_vol.unique()
# Out:
# array([' ',
#        '교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등, 보건의료 - 요양원 혈압, 혈당 검사, 호스피스 자원봉사 , 심폐소생술 홍보등, 환경 - 환경교육,  절전 캠페인등',
#        '생활 편의 지원 - 급식소 배식, 유아/노인 활동 보조, 차량 봉사 등, 상담 - 청소년 상담, 법률 상담,  수화통역 봉사등, 교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등, 보건의료 - 요양원 혈압, 혈당 검사, 호스피스 자원봉사 , 심폐소생술 홍보등, 문화체육 - 어린이 체육교실, 노인 음악 교실, 체육회 보조, 음악회 보조, 전시회 보조등, 농어촌 - 농어촌 야학, 농총활동등',
#        '교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등',
#        '상담 - 청소년 상담, 법률 상담,  수화통역 봉사등, 교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등, 환경 - 환경교육,  절전 캠페인등, 행정지원',
#        '환경 - 환경교육,  절전 캠페인등',
#        '생활 편의 지원 - 급식소 배식, 유아/노인 활동 보조, 차량 봉사 등, 상담 - 청소년 상담, 법률 상담,  수화통역 봉사등',
#        '교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등, 국제협력 - 번역,  NGO등, 행정지원',
#        '상담 - 청소년 상담, 법률 상담,  수화통역 봉사등',
#        '주거 환경 - 요양원 청소, 공공시설 환경미화 등, 문화체육 - 어린이 체육교실, 노인 음악 교실, 체육회 보조, 음악회 보조, 전시회 보조등',
#        '교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등, 인권 - 제 3세계, 청소년 노동인권등',
# ...

# %%
if df.favor_vol in '생활 편의 지원 - 급식소 배식, 유아/노인 활동 보조, 차량 봉사 등':
    print('getitii')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-250-87a35547c8f3> in <module>()
# ----> 1 if df.favor_vol in '생활 편의 지원 - 급식소 배식, 유아/노인 활동 보조, 차량 봉사 등':
#       2     print('getitii')
#
# TypeError: 'in <string>' requires string as left operand, not Series

# %%
data.favor_vol.replace('생활 편의 지원 - 급식소 배식, 유아/노인 활동 보조, 차량 봉사 등',1, inplace=True)

# %%
data.favor_vol.replace('주거 환경 - 요양원 청소, 공공시설 환경미화 등', 2, inplace=True)

# %%
data.favor_vol.replace('상담 - 청소년 상담, 법률 상담,  수화통역 봉사등', 3, inplace=True)

# %%
data.favor_vol.replace('교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등',4, inplace=True)

# %%
data.favor_vol.replace('보건의료 - 요양원 혈압, 혈당 검사, 호스피스 자원봉사 , 심폐소생술 홍보등',5, inplace=True)

# %%
data.favor_vol.replace('문화체육 - 어린이 체육교실, 노인 음악 교실, 체육회 보조, 음악회 보조, 전시회 보조등',6, inplace=True)

# %%
data.favor_vol.replace('환경 - 환경교육,  절전 캠페인등, 재해/ 재난 - 심폐소생술 교육, 구호활동',7, inplace=True)

# %%
data.favor_vol.replace('인권 - 제 3세계, 청소년 노동인권등',8, inplace=True)

# %%
data.favor_vol.replace('국제협력 - 번역,  NGO등',9, inplace=True)

# %%
data.favor_vol.replace('농어촌 - 농어촌 야학, 농총활동등',10, inplace=True)

# %%
data.favor_vol.replace('행정지원',11, inplace=True)

# %%
data.favor_vol.replace('재해/ 재난 - 심폐소생술 교육, 구호활동',12, inplace=True)

# %%
data.favor_vol.replace('관심없음',13, inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 16 columns):
# timestamp           94 non-null object
# sex                 94 non-null object
# age                 94 non-null int64
# univ                88 non-null object
# major               94 non-null object
# grade               93 non-null float64
# entrance_year       94 non-null int64
# hobby               67 non-null object
# residential_area    90 non-null object
# favor_vol           94 non-null object
# experience_vol      94 non-null object
# location_vol        90 non-null object
# interest_vol        94 non-null object
# frequence           94 non-null object
# vol_hour_in_day     89 non-null object
# total_hour          94 non-null object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 11.8+ KB

# %%
df2.total_hour.replace('생각안남',0, inplace=True)

# %%
df2.total_hour.replace('모르겠음',0, inplace=True)

# %%
df2.total_hour.replace('없음',0, inplace=True)

# %%
df2[df2.total_hour==300]
# Out:
#                 timestamp sex  age   univ  major  grade  entrance_year hobby  \
# 1   2018. 8. 8 오후 6:02:27   남   26  건국대학교  산업디자인    4.0           2012    드럼
# 84  2018. 8. 8 오후 6:23:59   여   23  한양대학교  전기공학과    4.0           2015  음악듣기
#
#    residential_area                      favor_vol  \
# 1      서울시 동대문구 전농동                           관심없음
# 84          관악구 봉천동  상담 - 청소년 상담, 법률 상담,  수화통역 봉사등
#
#                                        experience_vol  location_vol  \
# 1   생활 편의 지원 - 급식소 배식, 유아/노인 활동 보조, 차량 봉사 등, 주거 환경...  서울시 동대문구 전농동
# 84                      상담 - 청소년 상담, 법률 상담,  수화통역 봉사등    서울 성동구 행당동
#
#    interest_vol       frequence vol_hour_in_day  total_hour
# 1       청소년, 환경     3년에 1회 - 2회   3시간 이상 4시간 미만       300.0
# 84          청소년  3개월에 1 회 - 2 회   3시간 이상 4시간 미만       300.0

# %%
df2.total_hour = df.total_hour.astype('float64',inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 16 columns):
# timestamp           94 non-null object
# sex                 94 non-null object
# age                 94 non-null int64
# univ                94 non-null object
# major               94 non-null object
# grade               93 non-null float64
# entrance_year       94 non-null int64
# hobby               67 non-null object
# residential_area    90 non-null object
# favor_vol           94 non-null object
# experience_vol      94 non-null object
# location_vol        90 non-null object
# interest_vol        94 non-null object
# frequence           94 non-null object
# vol_hour_in_day     89 non-null object
# total_hour          94 non-null float64
# dtypes: float64(2), int64(2), object(12)
# memory usage: 11.8+ KB

# %%
age = df2.groupby('age').mean()

# %% [markdown]
# ## Visualization

# %%
plt.style.use('ggplot')

# %%
#나이별 총 봉사활동 시간
age.total_hour.plot.bar()

# %%
age.entrance_year.plot.bar()

# %%
age.grade.plot.bar()

# %%
df2.head()
# Out:
#                 timestamp sex  age   univ major  grade  entrance_year hobby  \
# 0   2018. 8. 2 오후 2:41:52   남   25    NaN          2.0           2017   NaN
# 1   2018. 8. 8 오후 6:17:30   여   22  삼육대학교  간호학과    3.0           2016   NaN
# 2  2018. 8. 9 오후 12:44:16   여   20  한양대학교  간호학과    1.0           2018    운동
# 3  2018. 8. 8 오후 10:57:03   남   27  한양대학교  건설학과    4.0           2013  미드보기
# 4   2018. 8. 8 오후 5:22:02   남   24  한양대학교  건설학과    1.0           2016    운동
#
#    residential_area                                          favor_vol  \
# 0               NaN
# 1       서울시 노원구 중계동  교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등, 보건의료 - 요양원 ...
# 2  서울특별시 은평로 21길 52  생활 편의 지원 - 급식소 배식, 유아/노인 활동 보조, 차량 봉사 등, 상담 - ...
# 3         서울 중구 약수동                  교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등
# 4      서울시 서초구 방배3동  상담 - 청소년 상담, 법률 상담,  수화통역 봉사등, 교육 - 방과후 교육, 초등...
#
#                                       experience_vol           location_vol  \
# ...

# %%
fav = df2.groupby('favor_vol').major.count()

# %%
fav
# Out:
# favor_vol
#                                                                                                                                                                                                                                                        1
# 관심없음                                                                                                                                                                                                                                                   4
# 교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등                                                                                                                                                                                                                     16
# ...

# %%
fav.plot.bar()

# %%
major = df2.groupby('major').mean()

# %%
major.total_hour.plot.bar()

# %%
gender = df2.groupby('sex').mean()

# %%
gender.total_hour.plot.bar()

# %%
univ = df2.groupby('univ').mean()

# %%
univ.total_hour.plot.bar()

# %%
grade = df2.groupby('grade').mean()

# %%
grade.total_hour.plot.bar()

# %%
df.head()
# Out:
#                 timestamp sex  age   univ major  grade  entrance_year hobby  \
# 0   2018. 8. 2 오후 2:41:52   남   25    NaN          2.0           2017   NaN
# 1   2018. 8. 8 오후 6:17:30   여   22  삼육대학교  간호학과    3.0           2016   NaN
# 2  2018. 8. 9 오후 12:44:16   여   20  한양대학교  간호학과    1.0           2018    운동
# 3  2018. 8. 8 오후 10:57:03   남   27  한양대학교  건설학과    4.0           2013  미드보기
# 4   2018. 8. 8 오후 5:22:02   남   24  한양대학교  건설학과    1.0           2016    운동
#
#    residential_area                                          favor_vol  \
# 0               NaN
# 1       서울시 노원구 중계동  교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등, 보건의료 - 요양원 ...
# 2  서울특별시 은평로 21길 52  생활 편의 지원 - 급식소 배식, 유아/노인 활동 보조, 차량 봉사 등, 상담 - ...
# 3         서울 중구 약수동                  교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등
# 4      서울시 서초구 방배3동  상담 - 청소년 상담, 법률 상담,  수화통역 봉사등, 교육 - 방과후 교육, 초등...
#
#                                       experience_vol           location_vol  \
# ...

# %%
df2.head()
# Out:
#                 timestamp sex  age   univ    major  grade  entrance_year  \
# 0   2018. 8. 8 오후 3:32:48   남   25  가천대학교     경영학과    4.0           2013
# 1   2018. 8. 8 오후 6:02:27   남   26  건국대학교    산업디자인    4.0           2012
# 2   2018. 8. 8 오후 6:32:33   여   22  경희대학교   아동가족학과    3.0           2016
# 3   2018. 8. 6 오후 5:19:38   여   22  고려대학교   국어국문학과    3.0           2016
# 4  2018. 8. 7 오후 11:24:25   남   23  고려대학교  바이오의공학부    2.0           2015
#
#           hobby residential_area  \
# 0          영화감상   경기 성남시 분당구 야탑동
# 1            드럼     서울시 동대문구 전농동
# 2  자전거타기 / 도배하기     서울시 노원구 하계2동
# 3           NaN      서울 동대문구 제기동
# 4     독서 / 음악감상      서울 동대문구 용두동
#
#                                            favor_vol  \
# 0  상담 - 청소년 상담, 법률 상담,  수화통역 봉사등, 교육 - 방과후 교육, 초등...
# 1                                               관심없음
# 2                  교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등
# 3  교육 - 방과후 교육, 초등 돌봄 교실, 노인 취미 교실 등, 인권 - 제 3세계,...
# ...

# %%
liberal_art=['경영학과', '산업디자인', '아동가족학과', '국어국문학과', '정치외교학과', '심리학과','지리교육과', \
                 '상담심리교육학과', '영어영문학과', '경제학과', '아동복지학과','제과제빵', '간호학과','일어일문학과', '문헌정보학과', \
                 '법학과','메카트로닉스', '유아교육과', '국제학부', '정책학과', '행정학과']

natural_science=['바이오의공학부','컴퓨터공학과','화학과','ITM','글로벌융합산업공학과','토목환경공학과','전기공학과','신소재공학과',\
                 '정보보호학과','임베디드시스템공학과','유기나노공학과','스포츠산업학과','실내건축디자인','건축학부','식품생물공학과',\
                 '소프트웨어','전자공학','건설학과','에너지신소재','식품영양학과', '기술경영융합']

# %%
len(liberal_art)
# Out:
# 21

# %%
len(natural_science)
# Out:
# 21

# %%
test = []
for value in df2.major :
    
    if value in liberal_art:
        test.append('문과')
    else :
        test.append('이과')

# if df2.major. in liberal_art:
#     df2.test = 0
# else :
#     df2.test =1

# %%
df2['test'] = test

# %%
df2.test
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-406-fac4d6664660> in <module>()
# ----> 1 df2.test
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'test'

# %%
test = df2.groupby('test').mean()

# %%
test.total_hour.plot.bar()

# %%
c = df2.groupby('univ').count()

# %%
c.timestamp.plot.bar()

# %%
df2.groupby('univ').mean()
# Out:
#                  age     grade  entrance_year  total_hour
# univ
# SNUT       24.000000  3.000000    2014.000000    0.000000
# 가천대학교      25.000000  4.000000    2013.000000    0.000000
# 건국대학교      26.000000  4.000000    2012.000000  300.000000
# 경희대학교      22.000000  3.000000    2016.000000    0.000000
# 고려대학교      24.894737  3.368421    2014.000000   51.315789
# 고졸         26.000000  3.666667    1679.333333   10.500000
# 국민대학교      26.000000  4.000000    2015.000000    0.000000
# 남서울대학교     22.000000  3.000000    2016.000000   60.000000
# 단국대학교      26.000000  4.000000    2014.000000    1.250000
# 명지대학교      25.333333  4.000000    2012.666667   38.500000
# 백석문화       22.000000       NaN    2016.000000  100.000000
# 삼육대학교      22.000000  3.000000    2016.000000  132.000000
# 서울과기대      22.111111  2.000000    2016.222222   67.888889
# 서울여자대학교    21.666667  2.666667    2016.000000   96.666667
# 세종대학교      22.750000  3.000000    2015.375000   85.375000
# ...
